# %%
import numpy as np
import pandas as pd
import altair as alt

# %%
old = pd.read_csv('./datasets/Stats 93-98.csv')
modern = pd.read_csv('./datasets/Stats 14-19.csv')

# %%
old.head()
# Out:
#                      Team     Year   G   W   L     MP    FG   FGA    FG%   3P  \
# 0            Phoenix Suns  1993-94  82  56  26  240.3  41.8  86.3  0.484  4.2
# 1   Golden State Warriors  1993-94  82  50  32  241.2  42.8  87.1  0.492  3.5
# 2  Portland Trail Blazers  1993-94  82  47  35  240.9  41.1  90.6  0.454  3.3
# 3       Charlotte Hornets  1993-94  82  41  41  241.8  41.2  86.6  0.476  4.1
# 4     Seattle SuperSonics  1993-94  82  63  19  240.6  40.7  84.2  0.484  3.0
#
#    ...    FT%   ORB   DRB   TRB   AST   STL  BLK   TOV    PF    PTS
# 0  ...  0.728  14.9  29.9  44.8  27.6   9.1  5.6  15.9  20.0  108.2
# 1  ...  0.664  14.4  29.2  43.6  26.8   9.8  6.2  17.5  21.8  107.9
# 2  ...  0.743  15.9  30.0  45.9  25.2   9.1  5.0  14.8  22.3  107.3
# 3  ...  0.764  12.4  30.2  42.6  27.0   8.8  4.8  15.4  21.3  106.5
# 4  ...  0.745  14.0  27.2  41.2  25.8  12.8  4.5  15.4  23.3  105.9
#
# [5 rows x 27 columns]

# %%
modern.head()
# Out:
#                     Team     Year   G   W   L     MP    FG   FGA    FG%    3P  \
# 0  Golden State Warriors  2018-19  82  67  15  240.6  41.6  87.0  0.478  10.8
# 1   Los Angeles Clippers  2018-19  82  56  26  240.6  39.4  83.3  0.473  10.1
# 2       Dallas Mavericks  2018-19  82  50  32  242.4  39.7  85.8  0.463   8.9
# 3        Toronto Raptors  2018-19  82  49  33  242.1  37.9  83.3  0.455   8.9
# 4  Oklahoma City Thunder  2018-19  82  45  37  241.8  38.8  86.8  0.447   7.7
#
#    ...    FT%   ORB   DRB   TRB   AST  STL  BLK   TOV    PF    PTS
# 0  ...  0.768  10.4  34.3  44.7  27.4  9.3  6.0  14.5  19.9  110.0
# 1  ...  0.710   9.6  33.1  42.6  24.8  7.8  5.0  12.3  21.3  106.7
# 2  ...  0.752  10.5  31.8  42.3  22.5  8.1  4.5  13.0  20.0  105.2
# 3  ...  0.787  10.7  30.8  41.5  20.7  7.5  4.4  12.9  20.9  104.0
# 4  ...  0.754  12.8  34.7  47.5  20.5  7.3  5.5  14.7  22.3  104.0
#
# [5 rows x 27 columns]

# %%
brush = alt.selection_interval()
points = alt.Chart(modern, title="How 3-point percentage correlates to wins").mark_point().encode(
    alt.X('W', scale=alt.Scale(zero=False)),
    alt.Y('3P%', scale=alt.Scale(zero=False)),
    color=alt.condition(brush, 'Team', alt.value('lightgray')),
    tooltip = [alt.Tooltip('Team'),
               alt.Tooltip('W'),
               alt.Tooltip('3P%'),
               alt.Tooltip('3P'),
               alt.Tooltip('Year')
              ]
).add_selection(
    brush
)


bar = alt.Chart(modern, title="How 3-point percentage correlates to wins").mark_bar().encode(
    y='Team',
    color='Team',
    x='3P',
).transform_filter(
    brush
)

points & bar
# Out:
# alt.VConcatChart(...)

# %%
brush = alt.selection_interval()
points = alt.Chart(old).mark_point().encode(
    alt.X('W', scale=alt.Scale(zero=False)),
    alt.Y('3P%', scale=alt.Scale(zero=False)),
    color=alt.condition(brush, 'Team', alt.value('lightgray')),
    tooltip = [alt.Tooltip('Team'),
               alt.Tooltip('W'),
               alt.Tooltip('3P%'),
               alt.Tooltip('3P'),
               alt.Tooltip('Year')
              ]
).add_selection(
    brush
)


bar = alt.Chart(old).mark_bar().encode(
    y='Team',
    color='Team',
    x='3P',
).transform_filter(
    brush
)
points & bar
# Out:
# alt.VConcatChart(...)

# %%
bars = alt.Chart(modern).mark_bar().encode(
    x=alt.X('3P%', stack='zero'),
    y=alt.Y('Team'),
    color=alt.Color('W')
)

text = alt.Chart(modern).mark_text(dx=-15, dy=3, color='white').encode(
    x=alt.X('3P%', stack='zero'),
    y=alt.Y('Team'),
    detail='W',
    text=alt.Text('3P%', format='.2f')
)

bars + text
# Out:
# alt.LayerChart(...)

# %%
bars = alt.Chart(old).mark_bar().encode(
    x=alt.X('3P%', stack='zero'),
    y=alt.Y('Team'),
    color=alt.Color('W')
)

text = alt.Chart(old).mark_text(dx=-15, dy=3, color='white').encode(
    x=alt.X('3P%', stack='zero'),
    y=alt.Y('Team'),
    detail='W',
    text=alt.Text('3P%', format='.2f')
)

bars + text
# Out:
# alt.LayerChart(...)

# %%
bars = alt.Chart(old).mark_bar().encode(
    x=alt.X('2P', stack='zero'),
    y=alt.Y('Team'),
    color=alt.Color('W')
)

text = alt.Chart(old).mark_text(dx=-15, dy=3, color='white').encode(
    x=alt.X('2P', stack='zero'),
    y=alt.Y('Team'),
    detail='W',
    text=alt.Text('2P', format='.2f')
)

bars + text
# Out:
# alt.LayerChart(...)

# %%
bars = alt.Chart(modern).mark_bar().encode(
    x=alt.X('2P', stack='zero'),
    y=alt.Y('Team'),
    color=alt.Color('W')
)

text = alt.Chart(modern).mark_text(dx=-15, dy=3, color='white').encode(
    x=alt.X('2P', stack='zero'),
    y=alt.Y('Team'),
    detail='W',
    text=alt.Text('2P', format='.2f')
)

bars + text
# Out:
# alt.LayerChart(...)

# %%
threepointers = pd.read_csv('./datasets/Modern 3 Pointers.csv')

# %%
threepointers.head()
# Out:
#     Year         Player Pos  Age   Tm   G  GS    MP   FG   FGA  ...    FT%  \
# 0  18-19   James Harden  PG   29  HOU  78  78  2867  843  1909  ...  0.879
# 1  18-19  Stephen Curry  PG   30  GSW  69  69  2331  632  1340  ...  0.916
# 2  18-19    Paul George  SF   28  OKC  77  77  2841  707  1614  ...  0.839
# 3  18-19    Buddy Hield  SG   26  SAC  82  82  2615  623  1360  ...  0.886
# 4  18-19   Kemba Walker  PG   28  CHO  82  82  2863  731  1684  ...  0.844
#
#    ORB    DRB    TRB    AST    STL   BLK    TOV     PF     PTS
# 0   66  452.0  518.0  586.0  158.0  58.0  387.0  244.0  2818.0
# 1   45  324.0  369.0  361.0   92.0  25.0  192.0  166.0  1881.0
# 2  105  523.0  628.0  318.0  170.0  34.0  205.0  214.0  2159.0
# 3  106  306.0  412.0  205.0   58.0  33.0  146.0  202.0  1695.0
# 4   52  309.0  361.0  484.0  102.0  34.0  211.0  131.0  2102.0
#
# [5 rows x 30 columns]

# %%
alt.Chart(threepointers).mark_point().encode(
    alt.X('G', scale=alt.Scale(zero=False)),
    alt.Y('3P', scale=alt.Scale(zero=False)),
    alt.Size('3P%'),
    color=alt.condition(brush, 'Tm', alt.value('lightgray')),
    tooltip = [alt.Tooltip('Player'),
               alt.Tooltip('Tm'),
               alt.Tooltip('3P'),
               alt.Tooltip('3P%'),
               alt.Tooltip('Year')
              ]
).add_selection(
    brush
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(modern).mark_rect().encode(
    alt.X('W', bin=alt.Bin(maxbins=60)),
    alt.Y('3P', bin=alt.Bin(maxbins=40)),
    alt.Color('W', scale=alt.Scale(scheme='greenblue'))
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(old).mark_rect().encode(
    alt.X('W', bin=alt.Bin(maxbins=80)),
    alt.Y('2P%', bin=alt.Bin(maxbins=60)),
    alt.Color('W', scale=alt.Scale(scheme='greenblue'))
)
# Out:
# alt.Chart(...)

# %%
oldCorrelation = pd.read_csv('./datasets/Stats 93-98.csv')
newCorrelation = pd.read_csv('./datasets/Stats 14-19.csv')
newCorrelation = newCorrelation.drop(['G'],axis=1)
oldCorrelation = oldCorrelation.drop(['G'],axis=1)

# %%
correlation = newCorrelation.corr().reset_index().melt('index')
correlation.columns = ['statsX', 'statsY', 'correlation']

heatmap = alt.Chart(correlation).mark_rect().encode(
    x=alt.X('statsX', title = 'X'),
    y=alt.Y('statsY', title = 'Y'),
    color=alt.Color('correlation'),
).properties(
    width=alt.Step(40),
    height=alt.Step(40)
)

heatmap += heatmap.mark_text(size=15).encode(
    text=alt.Text('correlation', format=".2f"),
    color=alt.condition(
        "datum.correlation > 0.5",
        alt.value('white'),
        alt.value('black')
    )
)

chart
# Out:
# alt.LayerChart(...)

# %%
corrMatrix = oldCorrelation.corr().reset_index().melt('index')
corrMatrix.columns = ['var1', 'var2', 'correlation']

chart = alt.Chart(corrMatrix).mark_rect().encode(
    x=alt.X('var1', title=None),
    y=alt.Y('var2', title=None),
    color=alt.Color('correlation', legend=None),
).properties(
    width=alt.Step(40),
    height=alt.Step(40)
)

chart += chart.mark_text(size=15).encode(
    text=alt.Text('correlation', format=".2f"),
    color=alt.condition(
        "datum.correlation > 0.5",
        alt.value('white'),
        alt.value('black')
    )
)

chart | chart.transform_filter("datum.var1 < datum.var2")
# Out:
# alt.HConcatChart(...)

# %%
lineBestFit = alt.Chart(modern).mark_point().encode(
    alt.X('W', scale=alt.Scale(zero=False)),
    alt.Y('DRB', scale=alt.Scale(zero=False)),
    tooltip = [alt.Tooltip('Team')
              ]
)
lineBestFit + lineBestFit.transform_regression('W', 'DRB').mark_line(color="red")
# Out:
# alt.LayerChart(...)

# %%
lineBestFit = alt.Chart(old).mark_point().encode(
    alt.X('W', scale=alt.Scale(zero=False)),
    alt.Y('DRB', scale=alt.Scale(zero=False))
)
lineBestFit + lineBestFit.transform_regression('W', 'DRB').mark_line(color="red")
# Out:
# alt.LayerChart(...)

# %%
alt.Chart(modern).mark_circle().encode(
    alt.X(alt.repeat("column"), type='quantitative', scale=alt.Scale(zero=False)),
    alt.Y(alt.repeat("row"), type='quantitative', scale=alt.Scale(zero=False)),
    color='Year:N'
).properties(
    width=150,
    height=150
).repeat(
    row=['W', 'DRB', 'STL'],
    column=['STL', 'DRB', 'W']
)
# Out:
# alt.RepeatChart(...)

# %%
old2P = alt.Chart(old).mark_point().encode(
    alt.X('Team', scale=alt.Scale(zero=False)),
    alt.Y('2P', scale=alt.Scale(zero=False))
)
old2P
# Out:
# alt.Chart(...)

# %%
new2P = alt.Chart(modern).mark_point().encode(
    alt.X('Team', scale=alt.Scale(zero=False)),
    alt.Y('2P', scale=alt.Scale(zero=False))
)
new2P
# Out:
# alt.Chart(...)

# %%
bars = alt.Chart(modern).mark_bar().encode(
    x=alt.X('3PA', stack='zero'),
    y=alt.Y('Team'),
    color=alt.Color('Year')
)

text = alt.Chart(modern).mark_text(dx=-15, dy=3, color='white').encode(
    x=alt.X('3PA', stack='zero'),
    y=alt.Y('Team'),
    detail='Year',
    text=alt.Text('3PA', format='.2f')
)

bars + text
# Out:
# alt.LayerChart(...)

# %%
bars = alt.Chart(old).mark_bar().encode(
    x=alt.X('3PA', stack='zero'),
    y=alt.Y('Team'),
    color=alt.Color('Year')
)

text = alt.Chart(old).mark_text(dx=-15, dy=3, color='white').encode(
    x=alt.X('3PA', stack='zero'),
    y=alt.Y('Team'),
    detail='Year',
    text=alt.Text('3PA', format='.2f')
)

bars + text
# Out:
# alt.LayerChart(...)

# %%
bars = alt.Chart(modern).mark_bar().encode(
    x=alt.X('BLK', stack='zero'),
    y=alt.Y('Team'),
    color=alt.Color('Year')
)

text = alt.Chart(modern).mark_text(dx=-15, dy=3, color='white').encode(
    x=alt.X('BLK', stack='zero'),
    y=alt.Y('Team'),
    detail='Year',
    text=alt.Text('BLK', format='.2f')
)

bars + text
# Out:
# alt.LayerChart(...)

# %%
bars = alt.Chart(old).mark_bar().encode(
    x=alt.X('BLK', stack='zero'),
    y=alt.Y('Team'),
    color=alt.Color('Year')
)

text = alt.Chart(old).mark_text(dx=-15, dy=3, color='white').encode(
    x=alt.X('BLK', stack='zero'),
    y=alt.Y('Team'),
    detail='Year',
    text=alt.Text('BLK', format='.2f')
)

bars + text
# Out:
# alt.LayerChart(...)
