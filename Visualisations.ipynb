# %%
import platform
import numpy as np
import pandas as pd
import sklearn as sk
import altair as alt
import os

# %%
teams = pd.read_csv('./datasets/2018-19 Team Stats.csv')

# %%
teams.head()
# Out:
#    Rk                   Team   G   W   L     MP    FG   FGA    FG%    3P  ...  \
# 0   1        Milwaukee Bucks  82  60  22  241.2  43.4  91.1  0.476  13.5  ...
# 1   2  Golden State Warriors  82  57  25  241.5  44.0  89.8  0.491  13.3  ...
# 2   3   New Orleans Pelicans  82  33  49  240.9  43.7  92.2  0.473  10.3  ...
# 3   4     Philadelphia 76ers  82  51  31  241.5  41.5  88.2  0.471  10.8  ...
# 4   5   Los Angeles Clippers  82  48  34  241.8  41.3  87.5  0.471  10.0  ...
#
#      FT%   ORB   DRB   TRB   AST  STL  BLK   TOV    PF    PTS
# 0  0.773   9.3  40.4  49.7  26.0  7.5  5.9  13.9  19.6  118.1
# 1  0.801   9.7  36.5  46.2  29.4  7.6  6.4  14.3  21.4  117.7
# 2  0.761  11.1  36.2  47.3  27.0  7.4  5.4  14.8  21.1  115.4
# 3  0.771  10.9  36.9  47.8  26.9  7.4  5.3  14.9  21.3  115.2
# 4  0.792   9.7  35.8  45.5  24.0  6.8  4.7  14.5  23.3  115.1
#
# [5 rows x 27 columns]

# %%
team1 = teams.iloc[:1]
brush = alt.selection_interval()

alt.Chart(teams).mark_point().encode(
    x='W:Q',
    y='3P:Q',
    color=alt.condition(brush, 'Team', alt.value('lightgray'))
).add_selection(
    brush
)
# Out:
# alt.Chart(...)

# %%
team1 = teams.iloc[:1]

alt.Chart(teams).mark_bar().encode(
    x='Team',
    y='3PA',
    color=('Team')
)
# Out:
# alt.Chart(...)

# %%
team1 = teams.iloc[:1]

points = alt.Chart(teams).mark_point().encode(
    alt.X('W', scale=alt.Scale(zero=False)),
    alt.Y('3P', scale=alt.Scale(zero=False)),
    color=alt.condition(brush, 'Team', alt.value('lightgray')),
    tooltip = [alt.Tooltip('Team'),
               alt.Tooltip('W'),
               alt.Tooltip('3P')
              ]
).add_selection(
    brush
)


bar = alt.Chart(teams).mark_bar().encode(
    y='Team',
    color='Team',
    x='3PA',
).transform_filter(
    brush
)
points & bar
# Out:
# alt.VConcatChart(...)

# %%
threepointers = pd.read_csv('./datasets/2017-18 3 Pointers.csv')

# %%
threepointers.head()
# Out:
#    Rk         Player Pos  Age   Tm   G  GS    MP   FG   FGA  ...    FT%  ORB  \
# 0   1   James Harden  SG   28  HOU  72  72  2551  651  1449  ...  0.858   41
# 1   2    Paul George  SF   27  OKC  79  79  2891  576  1340  ...  0.822   72
# 2   3     Kyle Lowry  PG   31  TOR  78  78  2510  403   944  ...  0.854   66
# 3   4   Kemba Walker  PG   27  CHO  80  80  2736  588  1363  ...  0.864   32
# 4   5  Klay Thompson  SG   27  GSW  73  73  2506  575  1179  ...  0.837   31
#
#    DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 0  348  389  630  126   50  315  169  2191
# 1  375  447  263  161   39  212  233  1734
# 2  368  434  537   85   19  183  192  1267
# 3  216  248  444   91   24  179   98  1770
# 4  246  277  185   55   34  128  117  1461
#
# [5 rows x 30 columns]

# %%
threepoint1 = threepointers.iloc[:1]

alt.Chart(threepointers).mark_point().encode(
    alt.X('G', scale=alt.Scale(zero=True)),
    alt.Y('3P', scale=alt.Scale(zero=True)),
    alt.Size('3P'),
    color=alt.condition(brush, 'Tm', alt.value('lightgray')),
    tooltip = [alt.Tooltip('Player'),
               alt.Tooltip('Tm'),
               alt.Tooltip('G'),
               alt.Tooltip('3P')
              ]
).add_selection(
    brush
)
# Out:
# alt.Chart(...)

# %%
teams2 = pd.read_csv('./datasets/2017-18 Team Stats.csv')

# %%
teams2.head()
# Out:
#    Rk                   Team   G   W   L     MP    FG   FGA    FG%    3P  ...  \
# 0   1  Golden State Warriors  82  58  24  240.6  42.8  85.1  0.503  11.3  ...
# 1   2        Houston Rockets  82  65  17  240.9  38.7  84.2  0.460  15.3  ...
# 2   3   New Orleans Pelicans  82  48  34  243.4  42.7  88.3  0.483  10.2  ...
# 3   4        Toronto Raptors  82  59  23  241.8  41.3  87.4  0.472  11.8  ...
# 4   5    Cleveland Cavaliers  82  50  32  240.6  40.4  84.8  0.476  12.0  ...
#
#      FT%  ORB   DRB   TRB   AST  STL  BLK   TOV    PF    PTS
# 0  0.815  8.4  35.1  43.5  29.3  8.0  7.5  15.5  19.6  113.5
# 1  0.781  9.0  34.5  43.5  21.5  8.5  4.8  13.8  19.5  112.4
# 2  0.772  8.7  35.7  44.3  26.8  8.0  5.9  14.9  19.1  111.7
# 3  0.794  9.8  34.2  44.0  24.3  7.6  6.1  13.4  21.7  111.7
# 4  0.779  8.5  33.7  42.1  23.4  7.1  3.8  13.7  18.6  110.9
#
# [5 rows x 27 columns]

# %%
team2 = teams2.iloc[:1]

points = alt.Chart(teams2).mark_point().encode(
    alt.X('W', scale=alt.Scale(zero=False)),
    alt.Y('3P', scale=alt.Scale(zero=False)),
    color=alt.condition(brush, 'Team', alt.value('lightgray')),
    tooltip = [alt.Tooltip('Team'),
               alt.Tooltip('W'),
               alt.Tooltip('3P')
              ]
).add_selection(
    brush
)


bar = alt.Chart(teams2).mark_bar().encode(
    y='Team',
    color='Team',
    x='3PA',
).transform_filter(
    brush
)
points & bar
# Out:
# alt.VConcatChart(...)

# %%
source = pd.read_csv('./datasets/2016-17 Team Stats.csv')

alt.Chart(source).mark_circle().encode(
    alt.X(alt.repeat("column"), type='quantitative'),
    alt.Y(alt.repeat("row"), type='quantitative'),
    color='Team'
).properties(
    width=150,
    height=150
).repeat(
    row=['W', '3P', '3PA'],
    column=['3PA', '3P', 'W']
).interactive()
# Out:
# alt.RepeatChart(...)

# %%
teams3 = pd.read_csv('./datasets/2016-17 Team Stats.csv')

team3 = teams3.iloc[:1]

points = alt.Chart(teams3).mark_point().encode(
    alt.X('W', scale=alt.Scale(zero=False)),
    alt.Y('3P', scale=alt.Scale(zero=False)),
    color=alt.condition(brush, 'Team', alt.value('lightgray')),
    tooltip = [alt.Tooltip('Team'),
               alt.Tooltip('W'),
               alt.Tooltip('3P')
              ]
).add_selection(
    brush
)


bar = alt.Chart(teams3).mark_bar().encode(
    y='Team',
    color='Team',
    x='3PA',
).transform_filter(
    brush
)
points & bar
# Out:
# alt.VConcatChart(...)

# %%
source = pd.read_csv('./datasets/2014-15 Team Stats.csv')

bars = alt.Chart(source).mark_bar().encode(
    x=alt.X('3PA', stack='zero'),
    y=alt.Y('Team'),
    color=alt.Color('W')
)

text = alt.Chart(source).mark_text(dx=-15, dy=3, color='white').encode(
    x=alt.X('3PA', stack='zero'),
    y=alt.Y('Team'),
    detail='W',
    text=alt.Text('3PA', format='.1f')
)

bars + text
# Out:
# alt.LayerChart(...)

# %%
source = pd.read_csv('./datasets/Stats 14-19.csv')

bars = alt.Chart(source).mark_bar().encode(
    x=alt.X('3PA', stack='zero'),
    y=alt.Y('Team'),
    color=alt.Color('W')
)

text = alt.Chart(source).mark_text(dx=-15, dy=3, color='white').encode(
    x=alt.X('3PA', stack='zero'),
    y=alt.Y('Team'),
    detail='W',
    text=alt.Text('3PA', format='.1f')
)

bars + text
# Out:
# alt.LayerChart(...)

# %%
teams4 = pd.read_csv('./datasets/Stats 14-19.csv')

points = alt.Chart(teams4).mark_point().encode(
    alt.X('W', scale=alt.Scale(zero=False)),
    alt.Y('3P', scale=alt.Scale(zero=False)),
    color=alt.condition(brush, 'Team', alt.value('lightgray')),
    tooltip = [alt.Tooltip('Team'),
               alt.Tooltip('W'),
               alt.Tooltip('3P'),
               alt.Tooltip('Year')
              ]
).add_selection(
    brush
)


bar = alt.Chart(teams4).mark_bar().encode(
    y='Team',
    color='Team',
    x='3PA',
).transform_filter(
    brush
)
points & bar
# Out:
# alt.VConcatChart(...)
